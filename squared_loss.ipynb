# %%
# standard libraries
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# modules from particles
import particles  # core module
from particles import distributions as dists  # where probability distributions are defined
from particles import state_space_models as ssms  # where state-space models are defined
from particles.collectors import Moments

# %%
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.rcParams['text.usetex'] = True
plt.rcParams["font.family"] = 'cmunrm'

# %%
maxW_d10_p1k_T50 = np.loadtxt('maxW_d10_p1k_T50.txt').tolist()
maxW_d10_p10k_T50 = np.loadtxt('maxW_d10_p10k_T50.txt').tolist()
maxW_d10_p100k_T50 = np.loadtxt('maxW_d10_p100k_T50.txt').tolist()

maxW_d100_p1k_T50 = np.loadtxt('maxW_d100_p1k_T50.txt').tolist()
maxW_d100_p10k_T50 = np.loadtxt('maxW_d100_p10k_T50.txt').tolist()
maxW_d100_p100k_T50 = np.loadtxt('maxW_d100_p100k_T50.txt').tolist()

maxW_d1000_p1k_T50 = np.loadtxt('maxW_d1000_p1k_T50.txt').tolist()
maxW_d1000_p10k_T50 = np.loadtxt('maxW_d1000_p10k_T50.txt').tolist()
maxW_d1000_p100k_T50 = np.loadtxt('maxW_d1000_p100k_T50.txt').tolist()

# %%
sns.set(style='ticks')
fig, axs = plt.subplots(3,3, figsize=(10,8), dpi=1200)
bins = [i/20 for i in range(21)]

axs[0,0].hist(maxW_d10_p1k_T50, bins=bins, color='darkgray', edgecolor='black', linewidth=0.5)
axs[0,0].plot(np.mean(maxW_d10_p1k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[0,0].set_xlabel(r'max $w_T$', fontsize=14)
axs[0,0].set_title(r'$N=10^3$', weight=1000)
axs[0,0].set_ylabel('occurences' + '\n' + r'$d_x=10$', fontname='cmunrm')
axs[0,0].set_xticks(np.arange(0, 1.2, 0.2))
axs[0,0].set_yticks(np.arange(0, 1200, 200))
axs[0,0].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=10$' + '\n' + r'$N=10^3$'
#axs[0,0].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[0,1].hist(maxW_d10_p10k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[0,1].plot(np.mean(maxW_d10_p10k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[0,1].set_xlabel(r'max $w_T$', fontsize=14)
axs[0,1].set_title(r'$N=10^4$')
axs[0,1].set_ylabel('')
axs[0,1].set_xticks(np.arange(0, 1.2, 0.2))
#axs[0,1].set_yticks(np.arange(0, 1000, 100))
axs[0,1].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=10$' + '\n' + r'$N=10^4$'
#axs[0,1].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[0,2].hist(maxW_d10_p100k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[0,2].plot(np.mean(maxW_d10_p100k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[0,2].set_xlabel(r'max $w_T$', fontsize=14)
axs[0,2].set_title(r'$N=10^5$')
axs[0,2].set_ylabel('')
axs[0,2].set_xticks(np.arange(0, 1.2, 0.2))
#axs[0,2].set_yticks(np.arange(0, 1000, 100))
axs[0,2].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=10$' + '\n' + r'$\mathrm{N=10^5}$'
#axs[0,2].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[1,0].hist(maxW_d100_p1k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[1,0].plot(np.mean(maxW_d100_p1k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[1,0].set_xlabel(r'max $w_T$', fontsize=14)
#axs[1,0].set_ylabel('occurences' + '\n' + r'$d_x=10$')
axs[1,0].set_xticks(np.arange(0, 1.2, 0.2))
axs[1,0].set_yticks(np.arange(0, 950, 200))
axs[1,0].set_ylabel('occurences' + '\n' + r'$d_x=100$', fontname='cmunrm')
axs[1,0].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=100$' + '\n' + r'$N=10^3$'
axs[1,0].set_ylim(0, 1000)
#axs[1,0].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[1,1].hist(maxW_d100_p10k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[1,1].plot(np.mean(maxW_d100_p10k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[1,1].set_xlabel(r'max $w_T$', fontsize=14)
axs[1,1].set_ylabel('')
axs[1,1].set_xticks(np.arange(0, 1.2, 0.2))
axs[1,1].set_yticks(np.arange(0, 950, 200))
axs[1,1].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=100$' + '\n' + r'$N=10^4$'
#axs[1,1].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))
axs[1,1].set_ylim(0, 1000)

axs[1,2].hist(maxW_d100_p100k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[1,2].plot(np.mean(maxW_d100_p100k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
#axs[1,2].set_xlabel(r'max $w_T$', fontsize=14)
axs[1,2].set_ylabel('')
axs[1,2].set_xticks(np.arange(0, 1.2, 0.2))
axs[1,2].set_yticks(np.arange(0, 950, 200))
axs[1,2].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=100$' + '\n' + r'$N=10^5$'
#axs[1,2].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))
axs[1,2].set_ylim(0, 1000)

axs[2,0].hist(maxW_d1000_p1k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[2,0].plot(np.mean(maxW_d1000_p1k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
axs[2,0].set_xlabel(r'max $w_T$', fontsize=14)
#axs[2,0].set_ylabel('occurences' + '\n' + r'$d_x=100$')
axs[2,0].set_xticks(np.arange(0, 1.2, 0.2))
#axs[2,0].set_yticks(np.arange(0, 800, 100))
axs[2,0].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=1000$' + '\n' + r'$N=10^3$'
#axs[2,0].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[2,1].hist(maxW_d1000_p10k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[2,1].plot(np.mean(maxW_d1000_p10k_T50), 12, 'rv', markersize=8)
#sns.despine(offset=1, trim=True)
axs[2,1].set_xlabel(r'max $w_T$', fontsize=14)
axs[2,1].set_ylabel('')
axs[2,1].set_xticks(np.arange(0, 1.2, 0.2))
#axs[2,1].set_yticks(np.arange(0, 800, 100))
axs[2,1].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=1000$' + '\n' + r'$N=10^4$'
#axs[2,1].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[2,2].hist(maxW_d1000_p100k_T50, bins=bins, color='darkgray', edgecolor='black',
             linewidth=0.5)
axs[2,2].plot(np.mean(maxW_d1000_p100k_T50), 12, 'rv', markersize=8)
axs[2,2].set_xlabel(r'max $w_T$', fontname='cmunrm', fontsize=14)
axs[2,2].set_ylabel('')
axs[2,2].set_xticks(np.arange(0, 1.2, 0.2))
#axs[2,2].set_yticks(np.arange(0, 800, 100))
axs[2,0].set_ylabel('occurences' + '\n' + r'$d_x=1000$', fontname='cmunrm')
axs[2,2].tick_params(axis='both', which='major', labelsize=11)
text = r'$d_x=1000$' + '\n' + r'$N=10^4$'
#axs[2,2].annotate(text,xy=(0.4,200), bbox=dict(fill=False, edgecolor='k',linewidth=0.75))

axs[0,0].sharey(axs[0,2])
axs[0,1].sharey(axs[0,2])

axs[1,0].sharey(axs[1,2])
axs[1,1].sharey(axs[1,2])

axs[2,1].sharey(axs[2,0])
axs[2,2].sharey(axs[2,0])


#sns.despine(offset=5, trim=True)

fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1, hspace=1)
fig.tight_layout()
#fig.savefig("cod_gaussian.pdf", format="pdf", bbox_inches="tight")
fig.show()
# Out:
#   fig.show()

# %%
round(sum(x > 0.5 for x in maxW_d1000_p100k_T50)/10,4)
# Out:
# 99.2

# %%
sns.set(style='ticks')

fig, axs = plt.subplots(figsize=(4,3), dpi=300)
dist_d10 = np.loadtxt('dist_d10.txt')
dist_d50 = np.loadtxt('dist_d50.txt')
dist_d100 = np.loadtxt('dist_d100.txt')
dist_d1000 = np.loadtxt('dist_d1000.txt').tolist()

data = {r'$d=10$':np.square(dist_d10),
       r'$d=50$':np.square(dist_d50),
       r'$d=100$':np.square(dist_d100)}

axs.boxplot(data.values())
#axs.set_xlabel('hello', fontname='cmr10')
axs.set_ylabel(r'$E\left[|x^\mathsf{c}_t-x_t|^2\right]$', fontname='cmr10')
axs.set_title(r'$(T=50, N=10^4, d_x={10,50,100})$',
              fontname='cmr10', pad=15)


axs.set_xticklabels(data.keys())
axs.tick_params(axis='both', which='major', labelfontfamily='cmr10')

fig.subplots_adjust(left=None, bottom=None, top=None, right=None, wspace=1, hspace=1)
fig.tight_layout()
fig.savefig("dist_all.pdf", format="pdf", bbox_inches="tight")
fig.show()
# Out:
#   fig.show()

# %%
print(np.mean(np.square(dist_d10)), np.mean(np.square(dist_d50)), np.mean(np.square(dist_d100)), np.mean(np.square(dist_d1000)))
# Out:
# 10.787613632465948 185.98011394296344 737.7422403481875 42109.204618452466
